# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.nn.functional as F
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import copy
import sys
from torch.utils.data import DataLoader, TensorDataset, Subset
from sklearn.model_selection import train_test_split
import ipyvolume as ipv

# %%
fileroot='2024_03_08_TRF_Maleen/'
filename='2024_03_08_TRF_Maleen_01'

datapath='/home/maleen/rosbags/Transformers/datasets/training/'

# Load the DataFrame from the pickle file
df1 = pd.read_pickle(datapath + filename + '.pkl')

arrays = [np.array(item) for item in df1['Skeleton_3D']]
timestamps = [np.array(item) for item in df1['Skeleton_Timestamp']]

# Convert datetime to seconds from start
timestamps = (timestamps - timestamps[0])

# Stack these arrays along a new axis to create a 3D NumPy array
# Each "slice" of this 3D array represents one frame of keypoints
skeleton_3d_frames = np.stack(arrays, axis=0)

# %%
#Create masks for the data (1 = data present, 0 = data missing)
# Correcting the mask values
masks = np.where(np.isnan(skeleton_3d_frames).any(axis=2), 0, 1)  # 0 for missing, 1 for present

# %%
# Calculate the differences in position and time
position_diff = np.diff(skeleton_3d_frames, axis=0)
time_diff = np.diff(timestamps)

# Ensure that time_diff is of shape (n,1,1) so that it broadcasts correctly when dividing
time_diff = time_diff[:, np.newaxis, np.newaxis]

# Update masks to match the dimensions of position_diff and time_diff
# We use the bitwise AND operator to ensure that both the current and previous frames are valid
masks_pos = masks[:-1, :] & masks[1:, :]

# Add an additional dimension to masks
masks_pos = masks_pos[:,:,np.newaxis]

# Now we calculate velocity, handling missing data according to the mask
# Where the mask is False, we will get np.nan
skel_vel = np.where(masks_pos, position_diff / time_diff, np.nan)

masks_velocity = masks_pos[:-1, :] & masks_pos[1:, :]

# Calculate the differences in velocity
velocity_diff = np.diff(skel_vel, axis=0)

# Now we calculate acceleration, handling missing data according to the mask
# Where the mask is False, we will get np.nan
skel_acc = np.where(masks_velocity, velocity_diff / time_diff[:-1, :, :], np.nan)  # Use time_diff with one less time dimension

# %%
# Now, slice skeleton_3d_frames and skel_vel to match the dimensions of skell_acc
skel_pos= skeleton_3d_frames[2:]
skel_vel = skel_vel[1:]
masks = masks[2:]

# %%
masks.shape
# Out:
# (1018, 18)

# %%
# Initialize arrays to hold the normalized data, medians, and IQRs
norm_pos = np.empty_like(skel_pos)
medians_per_joint_axis_skel_pos = np.empty((skel_pos.shape[1], skel_pos.shape[2]))
iqrs_per_joint_axis_skel_pos = np.empty((skel_pos.shape[1], skel_pos.shape[2]))

norm_vel= np.empty_like(skel_vel)
medians_per_joint_axis_vel = np.empty((skel_vel.shape[1], skel_vel.shape[2]))
iqrs_per_joint_axis_vel = np.empty((skel_vel.shape[1], skel_vel.shape[2]))

norm_acc = np.empty_like(skel_acc)
medians_per_joint_axis_acc = np.empty((skel_acc.shape[1], skel_acc.shape[2]))
iqrs_per_joint_axis_acc = np.empty((skel_acc.shape[1], skel_acc.shape[2]))

def robust_normalize_data_with_clipping(data, masks, medians_per_joint_axis, iqrs_per_joint_axis, normalized_data, clipping_percentiles=(1, 99)):
    for joint in range(data.shape[1]):  # For each joint
        for axis in range(data.shape[2]):  # For each axis (x, y, z)
            joint_axis_data = data[:, joint, axis]
            mask_for_joint = masks[:, joint]

            # Select valid data based on the mask
            valid_data = joint_axis_data[mask_for_joint == 1]

            # Determine clipping thresholds based on percentiles
            lower_threshold, upper_threshold = np.percentile(valid_data, clipping_percentiles) if valid_data.size > 0 else (np.nan, np.nan)

            # Clip the data based on valid mask and thresholds
            clipped_values = np.clip(joint_axis_data, lower_threshold, upper_threshold)

            # Calculate median and IQR for clipped data
            median = np.median(clipped_values[mask_for_joint == 1]) if np.any(mask_for_joint == 1) else np.nan
            q75, q25 = np.percentile(clipped_values[mask_for_joint == 1], [75 ,25]) if np.any(mask_for_joint == 1) else (np.nan, np.nan)
            iqr = q75 - q25

            # Store the calculated medians and IQRs
            medians_per_joint_axis[joint, axis] = median
            iqrs_per_joint_axis[joint, axis] = iqr

            # Normalize the clipped data, avoiding division by zero
            if iqr > 0:
                normalized_values = (clipped_values - median) / iqr
            else:
                normalized_values = clipped_values  # Keep original values if IQR is 0 or nan

            # Apply normalization only where data is present
            normalized_data[:, joint, axis] = np.where(mask_for_joint == 1, normalized_values, np.nan)
            
    return normalized_data, medians_per_joint_axis, iqrs_per_joint_axis

# Example usage with your data
# Note: masks, skel_pos, skel_vel, skel_acc should be defined in your context

norm_pos, medians_pos, iqrs_pos = robust_normalize_data_with_clipping(skel_pos, masks, medians_per_joint_axis_skel_pos, iqrs_per_joint_axis_skel_pos, norm_pos)
norm_vel, medians_vel, iqrs_vel = robust_normalize_data_with_clipping(skel_vel, masks, medians_per_joint_axis_vel, iqrs_per_joint_axis_vel, norm_vel)
norm_acc, medians_acc, iqrs_acc = robust_normalize_data_with_clipping(skel_acc, masks, medians_per_joint_axis_acc, iqrs_per_joint_axis_acc, norm_acc)

# %%
data=skel_acc
norm_data=norm_acc
# Plot the original and normalized data for a specific joint and axis
joint, axis = 0, 0  # Change as needed
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(data[:, joint, axis], bins=20, alpha=0.7, label='Original')
plt.title("Original Data Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.subplot(1, 2, 2)
plt.hist(norm_data[:, joint, axis], bins=20, alpha=0.7, label='Normalized')
plt.title("Normalized Data Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# Check the median and range of the normalized data
normalized_median = np.nanmedian(norm_data[:, joint, axis])
print("Median of normalized data:", normalized_median)

within_iqr = ((norm_data[:, joint, axis] > -2) & (norm_data[:, joint, axis] < 2)).sum()
print(f"Data points within [-1, 1] (IQR): {within_iqr} out of {norm_data.shape[0]}")

within_iqr2 = ((data[:, joint, axis] > -1) & (data[:, joint, axis] < 1)).sum()
print(f"Data points within [-1, 1] (IQR): {within_iqr2} out of {norm_data.shape[0]}")
# Out:
# Median of normalized data: -1.4094628242311558e-18
# Data points within [-1, 1] (IQR): 925 out of 1018
# Data points within [-1, 1] (IQR): 688 out of 1018

# %%
class SkeletalInputEmbedding(nn.Module):
    def __init__(self, num_joints=18, dof=3, embed_dim=128, device='gpu'):
        super().__init__()
        self.num_joints = num_joints
        self.dof = dof
        self.embed_dim = embed_dim
        self.device = device  # Store the device

        self.joint_embed = nn.Linear(dof, embed_dim)
        # self.vel_embed = nn.Linear(dof, embed_dim)
        # self.acc_embed = nn.Linear(dof, embed_dim)

    #def forward(self, joint_positions, velocities, accelerations, mask=None):
    def forward(self, joint_positions, mask=None):
        # Replace NaNs in the input data
        joint_positions = torch.nan_to_num(joint_positions)
        # velocities = torch.nan_to_num(velocities)
        # accelerations = torch.nan_to_num(accelerations)


        # Embedding and combining the embeddings
        joint_embeddings = self.joint_embed(joint_positions)
        # vel_embeddings = self.vel_embed(velocities)
        # acc_embeddings = self.acc_embed(accelerations)
        combined_embeddings = joint_embeddings #+ vel_embeddings + acc_embeddings

        # Apply mask after NaN replacement
        if mask is not None:
            mask = mask.unsqueeze(-1)  # Add a dimension for the features
            combined_embeddings = combined_embeddings * mask

        # Calculate positional encoding dynamically
        seq_len = joint_positions.size(1)  # Assuming joint_positions is [seq_len, num_joints, dof]
        positional_encoding = self.get_sinusoidal_encoding(seq_len * self.num_joints, self.embed_dim)
        # print("Device of input embeddings:", combined_embeddings.device)
        # print("Device of positional encodings:", positional_encoding.device)

        positional_encoding = positional_encoding.view(seq_len, self.num_joints, self.embed_dim)

        combined_embeddings += positional_encoding.unsqueeze(0)  # Unsqueeze to add batch dimension for broadcasting
        combined_embeddings = combined_embeddings.view(-1, seq_len, self.num_joints, self.embed_dim)

        return combined_embeddings

    def get_sinusoidal_encoding(self, total_len, embed_dim):
        # Make sure the position tensor is created on the right device
        position = torch.arange(0, total_len, dtype=torch.float, device=self.device).unsqueeze(1)
    
        # Calculate the division term for sinusoidal encoding
        div_term = torch.exp(torch.arange(0, embed_dim, 2).float() * -(np.log(10000.0) / embed_dim)).to(self.device)
        div_term = div_term.unsqueeze(0)  # Reshape for broadcasting
    
        # Create the positional encoding matrix
        pe = torch.zeros(total_len, embed_dim, device=self.device)
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
    
        return pe

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, embed_dim, num_heads, num_layers, dropout_rate=0.1):
        super().__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.num_layers = num_layers
        self.dropout_rate = dropout_rate
        
        # Transformer Encoder Layers
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=self.embed_dim,
            nhead=self.num_heads,
            dropout=self.dropout_rate,
            batch_first=True
        )
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=self.num_layers)

    def forward(self, src, src_mask=None, src_key_padding_mask=None):
        """
        src: Tensor of shape (batch_size, seq_len, num_joints, embed_dim)
        src_mask: None or Tensor for masking in multi-head attention (not used in this example)
        src_key_padding_mask: Tensor of shape (batch_size, seq_len * num_joints) indicating which elements are padded
        """
        # Reshaping src to fit the transformer's input requirement
        
        batch_size, seq_len, num_joints, embed_dim = src.size()
        src = src.view(batch_size, seq_len * num_joints, embed_dim)  # Flatten seq_len and num_joints

        #print("SRC shape:", src.shape)

        # Applying Transformer Encoder
        output = self.transformer_encoder(src, mask=src_mask, src_key_padding_mask=src_key_padding_mask)
        
        # Reshape back to (batch_size, seq_len, num_joints, embed_dim)
        output = output.view(batch_size, seq_len, num_joints, embed_dim)
        return output

# %%
class TransformerDecoder(nn.Module):
    def __init__(self, embed_dim, num_heads, num_layers, num_joints, dropout_rate=0.1):
        super().__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.num_layers = num_layers
        self.dropout_rate = dropout_rate
        self.num_joints = num_joints

        # Transformer Decoder Layer
        decoder_layer = nn.TransformerDecoderLayer(
            d_model=self.embed_dim,
            nhead=self.num_heads,
            dropout=self.dropout_rate,
            batch_first=True
        )
        self.transformer_decoder = nn.TransformerDecoder(decoder_layer, num_layers=self.num_layers)

        # Output layer to convert decoder output to joint position dimension
        self.output_layer = nn.Linear(self.embed_dim, 3)  # Assuming output per joint is a 3D position

    # @staticmethod
    # def generate_square_subsequent_mask(sz):
    #     mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
    #     mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    #     return mask

    def forward(self, tgt, memory, tgt_mask=None, memory_mask=None, tgt_key_padding_mask=None, memory_key_padding_mask=None):
        """
        tgt: Tensor of shape (batch_size, output_seq_len, num_joints, embed_dim), initially could be start token or zero vectors
        memory: Tensor of shape (batch_size, input_seq_len * num_joints, embed_dim), output from the Transformer encoder
        tgt_mask: Mask to ensure the decoder's predictions are based only on past positions
        memory_mask: Optional, to mask encoder outputs if necessary
        tgt_key_padding_mask: Tensor of shape (batch_size, output_seq_len * num_joints) for masking target sequences
        memory_key_padding_mask: Tensor of shape (batch_size, input_seq_len * num_joints) for masking memory sequences
        """
        # Reshaping memory and target to fit the transformer's input requirement
        batch_size, input_seq_len, num_joints, embed_dim = memory.size()
        batch_size, output_seq_len, num_joints, embed_dim = tgt.size()
        memory = memory.view(batch_size, input_seq_len * num_joints, embed_dim)  # Ensure memory is correctly reshaped
        tgt = tgt.view(batch_size, output_seq_len * num_joints, embed_dim)  # Flatten output_seq_len and num_joints

        # Transformer Decoder
        output = self.transformer_decoder(
            tgt, memory, tgt_mask=tgt_mask, memory_mask=memory_mask,
            tgt_key_padding_mask=tgt_key_padding_mask, memory_key_padding_mask=memory_key_padding_mask
        )

        # Reshape back and project to joint position dimensions
        output = output.view(batch_size, output_seq_len, num_joints, embed_dim)
        output = self.output_layer(output)

        return output

# %%
def generate_sequences(norm_pos, norm_vel, norm_acc, mask, input_length=60, predict_length=60):
    num_frames = norm_pos.shape[0]
    num_joints = norm_pos.shape[1]

    # Calculate the total number of sequences we can create
    num_sequences = num_frames - input_length - predict_length + 1

    # Initialize arrays to store the input and target sequences
    X_pos = np.zeros((num_sequences, input_length, num_joints, 3))
    X_vel = np.zeros((num_sequences, input_length, num_joints, 3))
    X_acc = np.zeros((num_sequences, input_length, num_joints, 3))
    Y_pos = np.zeros((num_sequences, predict_length, num_joints, 3))
    Y_vel = np.zeros((num_sequences, predict_length, num_joints, 3))
    Y_acc = np.zeros((num_sequences, predict_length, num_joints, 3))
    X_mask = np.zeros((num_sequences, input_length, num_joints))
    Y_mask = np.zeros((num_sequences, predict_length, num_joints))

    # Create sequences
    for i in range(num_sequences):
        X_pos[i] = norm_pos[i:i + input_length]
        X_vel[i] = norm_vel[i:i + input_length]
        X_acc[i] = norm_acc[i:i + input_length]
        Y_pos[i] = norm_pos[i + input_length:i + input_length + predict_length]
        Y_vel[i] = norm_vel[i + input_length:i + input_length + predict_length]
        Y_acc[i] = norm_acc[i + input_length:i + input_length + predict_length]
        X_mask[i] = mask[i:i + input_length]
        Y_mask[i] = mask[i + input_length:i + input_length + predict_length]

    return X_pos, X_vel, X_acc, X_mask, Y_pos, Y_vel, Y_acc, Y_mask


def create_shifted_mask(seq_length, num_joints):
    # seq_length is the number of time steps
    # num_joints is the number of joints per time step
    total_length = seq_length * num_joints
    mask = torch.ones((total_length, total_length), dtype=torch.float32) * float('-inf')  # Start with everything masked
    for i in range(seq_length):
        for j in range(i + 1):  # Allow visibility up to and including the current time step
            start_row = i * num_joints
            end_row = start_row + num_joints
            start_col = j * num_joints
            end_col = start_col + num_joints
            mask[start_row:end_row, start_col:end_col] = 0.0  # Unmask the allowed region

    return mask

class MaskedMSELoss(nn.Module):
    def __init__(self):
        super(MaskedMSELoss, self).__init__()

    def forward(self, output, target, output_mask, target_mask):
        # Ensure that the masks are applied, and only the relevant positions are used in loss calculation
        masked_output = output * output_mask
        masked_target = target * target_mask

        # Compute the squared differences
        squared_diff = (masked_output - masked_target) ** 2

        # Apply masks to the squared differences
        # This step is technically not necessary if the masks for output and target are the same
        masked_squared_diff = squared_diff * output_mask * target_mask

        # Calculate the mean of the squared differences while avoiding division by zero
        # This only considers the number of elements that are included in the mask
        loss = masked_squared_diff.sum() / (output_mask * target_mask).sum().clamp(min=1)

        return loss

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the saved model weights
checkpoint = torch.load('/home/maleen/transformer_models/best_model.pth', map_location=device)
embed_dim = 128
num_heads = 8
num_layers = 6
num_joints = 18
dropout_rate = 0.1
input_length = 20
predict_length = 10
autoregressiveloops=10
batch_size = 1

# Initialize the models with the same configuration as during training
embedding = SkeletalInputEmbedding(num_joints=num_joints, dof=3, embed_dim=embed_dim,device=device).to(device)
encoder = TransformerEncoder(embed_dim, num_heads, num_layers, dropout_rate).to(device)
decoder = TransformerDecoder(embed_dim, num_heads, num_layers, num_joints, dropout_rate).to(device)

# Load state dicts
embedding.load_state_dict(checkpoint['embedding_state_dict'])
encoder.load_state_dict(checkpoint['encoder_state_dict'])
decoder.load_state_dict(checkpoint['decoder_state_dict'])

X_pos, X_vel, X_acc, X_mask, Y_pos, Y_vel, Y_acc, Y_mask = generate_sequences(norm_pos, norm_vel, norm_acc, masks, input_length, predict_length)

# Convert to PyTorch tensors
X_pos_tensor = torch.tensor(X_pos, dtype=torch.float32)
X_vel_tensor = torch.tensor(X_vel, dtype=torch.float32)
X_acc_tensor = torch.tensor(X_acc, dtype=torch.float32)
X_mask_tensor = torch.tensor(X_mask, dtype=torch.bool)

Y_pos_tensor = torch.tensor(Y_pos, dtype=torch.float32)
Y_vel_tensor = torch.tensor(Y_vel, dtype=torch.float32)
Y_acc_tensor = torch.tensor(Y_acc, dtype=torch.float32)
Y_mask_tensor = torch.tensor(Y_mask, dtype=torch.bool)

# Create the DataLoader for inference data
dataset = TensorDataset(X_pos_tensor, X_vel_tensor, X_acc_tensor, X_mask_tensor, Y_pos_tensor, Y_mask_tensor)
inference_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

# Prepare for autoregressive decoding
predicted_positions = []

criterion = MaskedMSELoss()

# Perform inference across all batches
for batch in inference_loader:
    X_pos_batch, X_vel_batch, X_acc_batch, X_mask_batch, Y_pos_batch, Y_mask_batch = [b.to(device) for b in batch]

    # Encoder pass
    src_key_padding_mask = ~X_mask_batch.view(batch_size, input_length * num_joints)
    input_embeddings = embedding(X_pos_batch, X_mask_batch)
    memory = encoder(input_embeddings, src_key_padding_mask=src_key_padding_mask)

    
    # Initialize the start token for decoding
    current_pos = X_pos_batch[:, -1:, :, :]
    current_mask = X_mask_batch[:,-1:,:]

    for i in range(autoregressiveloops):
        # Embed the current position
        Y_expected= Y_pos_batch[:,i:i+1,:,:]
        Y_mask_expected = Y_mask_batch[:,i:i+1,:]
        
        current_embeddings = embedding(current_pos, current_mask)
        # Decoder pass
        output = decoder(current_embeddings, memory, tgt_key_padding_mask=None, memory_key_padding_mask=src_key_padding_mask)
    
        # Update current_pos for the next prediction
        current_pos = output[:, :, :, :].detach()  # only take the last timestep
    
        predicted_positions.append(current_pos.squeeze().cpu().numpy())
    
        Xmask_expanded = current_mask.unsqueeze(-1).expand_as(output)
        Xmask_expanded = Xmask_expanded.where(~torch.isnan(output), torch.zeros_like(Xmask_expanded))
        output = output.where(~torch.isnan(output), torch.zeros_like(output))
        # masked_output = output * Xmask
    
        Ymask_expanded = Y_mask_expected.unsqueeze(-1).expand_as(Y_expected)
        Ymask_expanded = Ymask_expanded.where(~torch.isnan(Y_expected), torch.zeros_like(Ymask_expanded))
        Y_expected = Y_expected.where(~torch.isnan(Y_pos_batch), torch.zeros_like(Y_expected))
        # masked_y_pos = Y_pos_batch * Ymask
    
        # Compute loss
        
        loss = criterion(output, Y_expected, Xmask_expanded, Ymask_expanded)

        print(loss)

    
# Convert the list of predicted positions to a more manageable form, e.g., a NumPy array
predicted_positions = np.array(predicted_positions)

print("Predicted Positions:", predicted_positions)
# Out:
# tensor(0.4775, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1112, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7385, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3276, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9943, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1422, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1916, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9907, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9075, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2640, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4382, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2138, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8284, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7885, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0688, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2777, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2465, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2154, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3605, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5090, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4869, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2112, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3267, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7100, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6701, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4893, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6313, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0449, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1709, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8121, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4932, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5435, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2691, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6646, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8504, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2355, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6580, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8814, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4822, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3112, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8867, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5832, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1154, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7435, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1968, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3344, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0138, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9013, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1315, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5583, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2779, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7602, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3467, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0146, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1567, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8502, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8539, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0429, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9998, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5008, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1820, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7226, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3927, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9082, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7111, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7054, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9659, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0015, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3514, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5225, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0587, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7978, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2815, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1842, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2075, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3911, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6124, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9171, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3662, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5106, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3471, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9343, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7699, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9938, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3327, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3469, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7545, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0079, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2213, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4393, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0937, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3764, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4947, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7449, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7522, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9090, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2408, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2878, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3957, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2818, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5724, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9102, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3170, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6185, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1013, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4837, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6929, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8222, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4454, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4066, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9120, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2840, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7220, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3393, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6646, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0399, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0713, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.7015, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1605, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4683, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7943, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0744, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5269, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8493, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1138, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2287, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8670, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3718, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8794, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1757, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4047, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7105, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0890, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3338, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7193, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4949, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9441, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4664, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0122, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1025, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3423, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7200, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9769, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2637, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0888, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5800, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1700, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7146, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0143, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1864, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4803, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6694, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8724, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5719, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1277, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8625, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3926, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9240, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6040, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1536, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3234, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4776, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1111, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6001, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1674, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8441, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4244, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2226, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3826, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1447, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3509, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0124, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3522, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0147, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6574, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0784, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7947, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8162, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9665, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2946, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8530, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2991, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0712, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6621, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1762, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9475, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0652, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1643, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5089, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9358, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7810, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2927, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0138, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7518, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7116, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9176, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1851, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3111, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3270, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7850, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6450, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5865, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5945, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6963, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9147, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9575, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2210, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4462, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4843, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5237, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6433, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7808, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0941, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1307, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1346, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4153, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3321, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4330, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5791, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7765, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0763, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1080, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1529, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3020, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1894, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4433, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5714, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5968, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8372, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8150, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0132, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3216, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6134, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2203, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3590, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4968, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7080, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7380, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8953, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0895, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3609, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5439, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1809, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3253, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4462, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4731, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6058, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7275, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1594, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1923, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4757, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1790, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5092, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4234, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5731, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7019, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9803, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1172, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2663, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4384, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3746, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3477, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5498, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8110, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1671, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3379, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6651, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6704, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7646, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1155, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2048, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3847, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5871, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8905, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1530, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5913, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5853, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7712, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6078, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1635, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3888, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4710, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6769, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0088, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2745, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2426, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4505, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1192, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4071, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1217, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2713, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6046, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9047, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2344, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2643, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4212, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3122, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6138, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7957, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1739, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4655, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6088, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8202, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8755, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0562, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9063, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3104, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3835, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4660, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2083, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4296, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6645, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8037, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9549, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8113, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1585, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1709, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3602, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3559, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1098, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3166, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3950, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6123, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4265, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7686, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8626, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9632, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9636, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0017, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1384, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3553, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5227, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4004, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8079, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8448, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9509, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1001, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2669, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4172, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2583, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3812, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4040, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8856, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0221, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0908, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1729, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2191, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3631, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1058, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1729, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2338, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8247, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8645, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9900, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0838, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1016, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0948, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0271, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8242, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1268, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6822, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8099, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9352, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9173, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9709, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0335, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8358, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8012, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7163, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3989, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4107, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5425, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6404, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7662, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9050, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7500, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6638, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6235, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6819, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1262, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5327, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7141, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8188, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9970, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9976, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7902, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7019, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6914, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6679, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1579, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3601, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5140, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7493, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7773, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6669, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6037, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6957, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7421, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8428, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1186, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3368, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6098, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5695, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4955, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4754, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5149, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6223, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7971, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8277, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1525, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4273, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3662, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2903, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2331, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3456, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4119, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5956, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8100, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8940, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1422, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2551, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2981, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2350, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3476, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4296, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5417, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7480, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8792, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8097, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1031, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1817, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2501, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3778, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5150, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6402, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8216, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9006, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9310, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1158, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0795, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2107, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3743, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5126, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5891, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7887, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8414, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8930, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1033, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4790, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1017, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1615, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2939, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4921, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7132, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7132, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7312, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9184, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3678, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3859, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0588, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1297, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2458, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4291, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5766, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6701, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8814, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3244, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2441, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2725, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0688, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2098, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3474, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5376, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5686, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8130, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0889, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9756, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0775, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1002, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0679, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2568, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4657, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5647, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7038, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1695, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0490, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0050, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.7192, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8010, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0558, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1622, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2551, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3804, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7672, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6921, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8603, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8049, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.0317, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1133, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0915, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1640, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3719, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7666, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7051, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7424, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.7786, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.0837, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1278, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1393, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0737, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3064, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7421, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7384, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9386, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8936, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1416, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3228, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4800, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0811, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1223, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5413, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5848, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7910, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6580, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.0296, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3648, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6073, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4298, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4422, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2068, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9592, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9338, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9111, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4621, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8477, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3724, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0675, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0293, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3031, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4643, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3189, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3000, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9854, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5801, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3346, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1597, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2642, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6039, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3075, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4845, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3735, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8595, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5860, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4134, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4385, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5491, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7165, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6097, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6449, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4343, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9092, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0334, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2904, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3390, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5253, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7951, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6549, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6998, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7347, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3641, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5944, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0375, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1377, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1400, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2700, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1382, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3647, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4447, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3241, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7970, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9597, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0120, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3766, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2560, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4539, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5502, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5030, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6532, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6584, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8659, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6767, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9225, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0249, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3920, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6389, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8714, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8393, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0693, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1524, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4529, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8245, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9370, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1769, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2357, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5976, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5935, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8300, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9244, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0151, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2692, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3996, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6988, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9613, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8577, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.3915, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.3615, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.5206, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.0562, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.2557, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.9012, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(5.3641, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7756, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3287, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.0766, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0800, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4094, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0022, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6140, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5119, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9386, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6055, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3362, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8182, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9894, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3012, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7084, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2028, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5872, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1823, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8759, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4231, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9056, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4693, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5709, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1609, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6402, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3942, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7161, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9682, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5443, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5618, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0243, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3490, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4640, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(nan, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2308, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4763, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6812, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2458, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4116, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8538, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5301, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9563, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3628, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1132, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4522, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6261, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0930, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1639, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6564, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2838, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6734, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2343, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.6199, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2327, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3836, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6984, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7921, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1346, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7634, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1014, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6923, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9007, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.5076, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1064, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3965, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5948, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0276, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5943, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0190, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7279, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1324, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.9080, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.8017, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2075, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4107, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7220, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2992, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7547, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4240, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9086, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.7026, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.5271, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.3376, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1562, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4179, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8328, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4948, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1460, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6955, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.5953, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.5314, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.4771, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1410, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1709, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6281, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0861, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6203, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0413, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1157, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2035, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.3528, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.2309, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.0848, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2074, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5935, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1097, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4018, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4695, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6351, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.7225, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5614, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6426, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9339, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1881, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6276, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8082, device='cuda:0', grad_fn=<DivBackward0>)
# ...
# tensor(3.8572, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.9890, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(4.1416, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1710, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4098, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6856, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0186, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4800, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4662, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9455, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1321, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2621, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4324, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1387, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4421, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5832, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9656, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9325, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5046, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7622, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8734, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1513, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2912, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1498, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3047, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7102, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6452, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9877, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2629, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.8212, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0058, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1858, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3895, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0801, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5621, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3313, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7415, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9055, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1960, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5316, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9170, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4340, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.7938, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2993, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1024, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3115, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4423, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6460, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9470, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3015, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5810, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0181, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2203, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2893, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5593, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7738, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7148, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8921, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1984, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5648, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8898, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2964, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3565, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1573, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4973, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3738, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4000, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5628, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8540, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1832, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5910, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9786, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3048, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2488, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1853, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2522, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3891, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5385, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6453, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9339, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3037, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5840, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0594, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1035, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2320, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3264, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3937, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6406, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7484, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0982, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2151, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4785, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8604, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0541, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1724, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2888, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4083, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4989, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6971, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8263, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1766, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5655, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1234, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1002, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1669, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3078, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4182, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7392, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9333, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2643, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5597, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1798, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5735, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0986, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2274, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2995, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7329, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7964, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0465, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2226, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6188, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9450, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2250, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1110, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1590, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4961, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5178, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7771, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0126, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4306, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7805, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9817, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3463, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0428, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3269, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3157, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5221, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6452, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9481, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3091, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6238, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2536, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9870, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2965, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2988, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5187, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7471, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0624, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4147, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7844, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2670, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9465, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.1163, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0946, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3127, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4807, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5897, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8959, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2832, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8647, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5499, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5882, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.5353, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1163, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2815, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4491, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6439, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9483, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4941, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2157, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4862, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.6718, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7747, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0865, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2400, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4733, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7370, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2089, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6736, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7102, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8618, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2294, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2154, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1176, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2720, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4297, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8050, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2498, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4752, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6214, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8476, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8849, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9860, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0786, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3354, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7505, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4275, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6615, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8087, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8155, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7170, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7532, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8672, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1224, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5272, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1029, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1012, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1823, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2855, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2970, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2731, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.4850, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.9759, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1765, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7134, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7523, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7684, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8782, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0194, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1600, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8186, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3592, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4916, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3372, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2883, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2890, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3788, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4988, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7442, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2545, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8096, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0015, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1725, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1745, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2504, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4638, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.4797, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7077, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0816, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6044, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5772, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7090, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.1116, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0771, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1903, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3668, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5414, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0719, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.8002, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7666, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0079, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.4703, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.3144, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0788, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1719, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.3814, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8466, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5742, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6488, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6785, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.2346, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.9479, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.2415, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.0787, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2456, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8890, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5581, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6264, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.0090, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7654, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.6177, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.8003, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0396, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.1523, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5942, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2134, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5252, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.6210, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.3609, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.4570, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.5140, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(3.0260, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(2.7838, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.2723, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6925, device='cuda:0', grad_fn=<DivBackward0>)

# %%
def reverse_normalization(normalized_data, medians_per_joint_axis, iqrs_per_joint_axis, masks):
    original_data = np.empty_like(normalized_data)  # Initialize an array to hold the original data

    # Iterate over each joint and each axis
    for joint in range(normalized_data.shape[0]):
        for axis in range(normalized_data.shape[1]):
            # Retrieve the median and IQR for this joint and axis
            median = medians_per_joint_axis[joint, axis]
            iqr = iqrs_per_joint_axis[joint, axis]

            # Retrieve the normalized values for this joint and axis
            normalized_values = normalized_data[ joint, axis]

            # Calculate the original values based on the normalization formula
            original_values = (normalized_values * iqr) + median

            # Apply the mask to restore original data only where it was initially present
            mask_for_joint = masks[:, joint]
            original_data[ joint, axis] = np.where(mask_for_joint == 1, original_values, np.nan)

    return original_data

# %%
# Assuming `skeleton_3d_data[500]` is your input data

mask=np.array(X_mask_batch[0][0].cpu())
mask_expanded = np.tile(mask[:, np.newaxis], (1, predicted_positions[0].shape[1]))

mask_ones = np.ones((1, 18))

reversed_data = reverse_normalization(predicted_positions[0], medians_pos, iqrs_pos, mask_ones)

masked_reversed_data = np.where(mask_expanded, reversed_data, np.nan)

data = masked_reversed_data

# Filter out the NaN values from the first 18 keypoints
valid_keypoints = ~np.isnan(data[:18, :]).any(axis=1)  # Corrected version
filtered_data = data[:18][valid_keypoints]


# Define connections based on your body model
original_connections = [
    (16, 14),(14, 0),                #Right Head
    (17, 15),(15, 0),                #Left Head
    (0, 1),                          #Neck
    (1, 2), (2, 3), (3, 4),          # Right arm
    (1, 5), (5, 6), (6, 7),          # Left arm
    (1, 8), (8, 9), (9, 10),         # Right leg
    (1, 11), (11, 12), (12, 13),     # Left leg
    (8, 11)                          # Between hips
]

# Create a mapping from old indices to new indices after NaN removal
index_mapping = {old_index: new_index for new_index, old_index in enumerate(np.where(valid_keypoints)[0])}

# Create a new list of connections that only includes the valid keypoints
new_connections = [(index_mapping[start], index_mapping[end])
                   for start, end in original_connections
                   if start in index_mapping and end in index_mapping]

# Create the 3D scatter plot
ipv.figure()
scatter = ipv.scatter(filtered_data[:, 0], filtered_data[:, 1], filtered_data[:, 2], marker='sphere', size=2)

# Draw lines for the new skeletal links
for start, end in new_connections:
    ipv.plot(filtered_data[[start, end], 0], filtered_data[[start, end], 1], filtered_data[[start, end], 2], color='red')

# Show the plot
ipv.view(azimuth=0, elevation=-90)
ipv.show()

# %%
original_connections = [
    (16, 14), (14, 0),               # Right Head
    (17, 15), (15, 0),               # Left Head
    (0, 1),                          # Neck
    (1, 2), (2, 3), (3, 4),          # Right arm
    (1, 5), (5, 6), (6, 7),          # Left arm
    (1, 8), (8, 9), (9, 10),         # Right leg
    (1, 11), (11, 12), (12, 13),     # Left leg
    (8, 11)                          # Between hips
]


# First dataset processing (already provided code)
mask = np.array(X_mask_batch[0][0].cpu())
mask_expanded = np.tile(mask[:, np.newaxis], (1, predicted_positions[0].shape[1]))
mask_ones = np.ones((1, 18))
reversed_data = reverse_normalization(predicted_positions[0], medians_pos, iqrs_pos, mask_ones)
masked_reversed_data = np.where(mask_expanded, reversed_data, np.nan)
data = masked_reversed_data
valid_keypoints = ~np.isnan(data[:18, :]).any(axis=1)
filtered_data = data[:18][valid_keypoints]

# Create mapping from old indices to new indices after NaN removal
index_mapping = {old_index: new_index for new_index, old_index in enumerate(np.where(valid_keypoints)[0])}
# Create new connections for the first dataset
new_connections = [(index_mapping[start], index_mapping[end])
                   for start, end in original_connections
                   if start in index_mapping and end in index_mapping]

# Second dataset processing
mask_y = X_mask[0][0] # Assuming you need a similar mask or adjust accordingly
mask_expanded_y = np.tile(mask_y[:, np.newaxis], (1, Y_pos[0][0].shape[1]))
reversed_data_y = reverse_normalization(Y_pos[0][0], medians_pos, iqrs_pos, mask_ones)
masked_reversed_data_y = np.where(mask_expanded_y, reversed_data_y, np.nan)
data_y = masked_reversed_data_y
valid_keypoints_y = ~np.isnan(data_y[:18, :]).any(axis=1)
filtered_data_y = data_y[:18][valid_keypoints_y]

# Create mapping from old indices to new indices for the second dataset
index_mapping_y = {old_index: new_index for new_index, old_index in enumerate(np.where(valid_keypoints_y)[0])}
# Create new connections for the second dataset
new_connections_y = [(index_mapping_y[start], index_mapping_y[end])
                     for start, end in original_connections
                     if start in index_mapping_y and end in index_mapping_y]

# Plot configuration
ipv.figure()

# Plot first dataset
scatter = ipv.scatter(filtered_data[:, 0], filtered_data[:, 1], filtered_data[:, 2], color='blue', marker='sphere', size=2)
for start, end in new_connections:
    ipv.plot(filtered_data[[start, end], 0], filtered_data[[start, end], 1], filtered_data[[start, end], 2], color='red')

# Plot second dataset
scatter_y = ipv.scatter(filtered_data_y[:, 0], filtered_data_y[:, 1], filtered_data_y[:, 2], color='green', marker='sphere', size=2)
for start, end in new_connections_y:
    ipv.plot(filtered_data_y[[start, end], 0], filtered_data_y[[start, end], 1], filtered_data_y[[start, end], 2], color='lime')

ipv.view(azimuth=0, elevation=-90)
ipv.show()

# %%
predicted_positions[6]

# %%
mask
