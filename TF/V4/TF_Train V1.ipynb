# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.nn.functional as F
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import copy
import sys
from torch.utils.data import DataLoader, TensorDataset, Subset
from sklearn.model_selection import train_test_split
from embedding_layers import SkeletalInputEmbedding
from encoder_layers import TransformerEncoder
from decoder_layers import TransformerDecoder
import TF_helper_functions as hf
import pickle
import ipyvolume as ipv
import numpy as np
import ipywidgets as widgets
from IPython.display import display

# %%
datapath='/home/maleen/research_data/Transformers/datasets/khoa_datasets/'
# Base path and file information
base_name='24_08_29_training_norm'

weights_path='/home/maleen/research_data/Transformers/models/TF_tokenised/24_09_05_v3_best_model.pth'

filename=datapath+base_name+'.pkl'

datasetnum=1

def load_results_from_pickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

def process_all_datasets(results, input_length=60, predict_length=60):
    all_X_pos, all_X_vel, all_X_acc = [], [], []
    all_Y_pos, all_Y_vel, all_Y_acc = [], [], []
    discarded_frames = {}

    for i in range(1, datasetnum+1):  # Assuming you have 6 datasets
        dataset_key = f'dataset{i}'
        norm_pos = results[f'{dataset_key}_normpos']
        norm_vel = results[f'{dataset_key}_normvel']
        norm_acc = results[f'{dataset_key}_normacc']

        print(norm_pos.shape)

        # Generate sequences for this dataset
        X_pos, X_vel, X_acc, Y_pos, Y_vel, Y_acc = hf.generate_sequences(norm_pos, norm_vel, norm_acc, input_length, predict_length)
        
        all_X_pos.append(X_pos)
        all_X_vel.append(X_vel)
        all_X_acc.append(X_acc)
        all_Y_pos.append(Y_pos)
        all_Y_vel.append(Y_vel)
        all_Y_acc.append(Y_acc)

        # Calculate discarded frames
        total_frames = norm_pos.shape[0]
        used_frames = X_pos.shape[0] #+ input_length + predict_length - 1
        discarded = total_frames - used_frames
        discarded_frames[dataset_key] = discarded

    # Combine sequences from all datasets
    combined_X_pos = np.concatenate(all_X_pos)
    combined_X_vel = np.concatenate(all_X_vel)
    combined_X_acc = np.concatenate(all_X_acc)
    combined_Y_pos = np.concatenate(all_Y_pos)
    combined_Y_vel = np.concatenate(all_Y_vel)
    combined_Y_acc = np.concatenate(all_Y_acc)

    return (combined_X_pos, combined_X_vel, combined_X_acc, 
            combined_Y_pos, combined_Y_vel, combined_Y_acc, 
            discarded_frames)

# %%
input_length = 30
predict_length = 15

# Load the results
results = load_results_from_pickle(filename)

# Process all datasets and get combined sequences
(combined_X_pos, combined_X_vel, combined_X_acc, 
 combined_Y_pos, combined_Y_vel, combined_Y_acc, 
 discarded_frames) = process_all_datasets(results, input_length, predict_length)

print("Combined sequences shapes:")
print(f"X_pos shape: {combined_X_pos.shape}")
print(f"X_vel shape: {combined_X_vel.shape}")
print(f"X_acc shape: {combined_X_acc.shape}")
print(f"Y_pos shape: {combined_Y_pos.shape}")
print(f"Y_vel shape: {combined_Y_vel.shape}")
print(f"Y_acc shape: {combined_Y_acc.shape}")

print("\nDiscarded frames per dataset:")
for dataset, frames in discarded_frames.items():
    print(f"{dataset}: {frames} frames")
# Out:
# (6744, 6, 3)
# Combined sequences shapes:
# X_pos shape: (6715, 15, 6, 3)
# X_vel shape: (6715, 15, 6, 3)
# X_acc shape: (6715, 15, 6, 3)
# Y_pos shape: (6715, 15, 6, 3)
# Y_vel shape: (6715, 15, 6, 3)
# Y_acc shape: (6715, 15, 6, 3)
#
# Discarded frames per dataset:
# dataset1: 29 frames

# %%
# Assuming you have already defined your models and set up your training loop
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "CPU")

# Initialize models
embed_dim = 128
num_heads = 8
num_layers = 6
num_joints = 6
dropout_rate = 0.1
dof=3
input_dim = num_joints * dof
batch_size = 1


start_token = torch.zeros(1, num_joints, 3).to(device)  # Assuming start token

# Assuming sequence length
# input_length = 30
# predict_length = 2


# tgt_mask= create_shifted_mask((input_length-1), num_joints)
# tgt_mask = tgt_mask.to(device)

# Convert to PyTorch tensors
X_pos_tensor = torch.tensor(combined_X_pos, dtype=torch.float32)
X_vel_tensor = torch.tensor(combined_X_vel, dtype=torch.float32)
X_acc_tensor = torch.tensor(combined_X_acc, dtype=torch.float32)

Y_pos_tensor = torch.tensor(combined_Y_pos, dtype=torch.float32)
Y_vel_tensor = torch.tensor(combined_Y_vel, dtype=torch.float32)
Y_acc_tensor = torch.tensor(combined_Y_acc, dtype=torch.float32)

# Create the full dataset
full_dataset = TensorDataset(X_pos_tensor, X_vel_tensor, X_acc_tensor, Y_pos_tensor, Y_vel_tensor, Y_acc_tensor)

# Data loader

train_loader = DataLoader(full_dataset, batch_size=batch_size, shuffle=False)

#Defining Models
embedding = SkeletalInputEmbedding(input_dim).to(device)
encoder = TransformerEncoder(embed_dim, num_heads, num_layers, dropout_rate).to(device)
decoder = TransformerDecoder(embed_dim, num_heads, num_layers, num_joints, dropout_rate).to(device)

# Loss function
#criterion = nn.MSELoss()
criterion = hf.MaskedMSELoss()

# Optimizer
optimizer = optim.Adam(list(encoder.parameters()) + list(decoder.parameters()), lr=0.00001) #0.00001


# Training loop
num_epochs = 100
best_loss = float('inf')
train_losses = []

for epoch in range(num_epochs):
    encoder.train()
    decoder.train()
    total_loss = 0.0

    for batch in train_loader:
        # Unpack batch
        X_pos_batch, X_vel_batch, X_acc_batch, Y_pos_batch, Y_vel_batch, Y_acc_batch = batch

        # Memory Data
        X_pos_batch = X_pos_batch.to(device)
        X_vel_batch = X_vel_batch.to(device)

        inputembeddings = embedding(X_pos_batch, X_vel_batch)
       
        memory = encoder(inputembeddings, src_key_padding_mask=None)

        # Output Data
        Y_pos_batch = Y_pos_batch.to(device)
        Y_vel_batch = Y_vel_batch.to(device)

        #Target Data
        Y_pos_target=X_pos_batch[:, -1:, :, :]
        Y_vel_target=X_vel_batch[:, -1:, :, :]
    

        #Expected Data 
        
        Y_pos_expected=Y_pos_batch[:,-1:,:,:] #Change to beginning

        targetembeddings = embedding(Y_pos_target, Y_vel_target)

        # Perform forward pass through decoder
        output = decoder(targetembeddings, memory, tgt_key_padding_mask=None, memory_key_padding_mask=None)

        output = output.where(~torch.isnan(output), torch.zeros_like(output))
        Y_pos_expected = Y_pos_expected.where(~torch.isnan(Y_pos_expected), torch.zeros_like(Y_pos_expected))

                
        # print("input embeddings: ", np.shape(inputembeddings))
        # print("memory: ", np.shape(memory))
        #print("target: ", np.shape(targetembeddings))
        #print("output: ", np.shape(output))
        #print("Expected output: ", np.shape(Y_vel_batch))
        # Compute loss
        loss = criterion(output, Y_pos_expected)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accumulate total loss for the epoch
        total_loss += loss.item()

    # Calculate average loss for the epoch
    avg_loss = total_loss / len(train_loader)
    train_losses.append(avg_loss)
    
    # Print or log average loss for the epoch
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}')
    
    # Save model weights if the current epoch has the best loss
    if avg_loss < best_loss:
        best_loss = avg_loss
        torch.save({
            'epoch': epoch,
            'embedding_state_dict': embedding.state_dict(),
            'encoder_state_dict': encoder.state_dict(),
            'decoder_state_dict': decoder.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': avg_loss
        }, weights_path)
        print(f'Saved new best model with validation loss: {avg_loss:.4f}')


# Plot training loss
plt.plot(train_losses)
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title('Training Loss')
plt.show()
# Out:
# Epoch [1/100], Loss: 0.2169
# Saved new best model with validation loss: 0.2169
# Epoch [2/100], Loss: 0.2055
# Saved new best model with validation loss: 0.2055
# Epoch [3/100], Loss: 0.1884
# Saved new best model with validation loss: 0.1884
# Epoch [4/100], Loss: 0.1727
# Saved new best model with validation loss: 0.1727
# Epoch [5/100], Loss: 0.1617
# Saved new best model with validation loss: 0.1617
# Epoch [6/100], Loss: 0.1529
# Saved new best model with validation loss: 0.1529
# Epoch [7/100], Loss: 0.1439
# Saved new best model with validation loss: 0.1439
# Epoch [8/100], Loss: 0.1394
# Saved new best model with validation loss: 0.1394
# Epoch [9/100], Loss: 0.1342
# Saved new best model with validation loss: 0.1342
# Epoch [10/100], Loss: 0.1280
# Saved new best model with validation loss: 0.1280
# Epoch [11/100], Loss: 0.1248
# Saved new best model with validation loss: 0.1248
# Epoch [12/100], Loss: 0.1219
# Saved new best model with validation loss: 0.1219
# Epoch [13/100], Loss: 0.1179
# Saved new best model with validation loss: 0.1179
# Epoch [14/100], Loss: 0.1151
# Saved new best model with validation loss: 0.1151
# Epoch [15/100], Loss: 0.1122
# Saved new best model with validation loss: 0.1122
# Epoch [16/100], Loss: 0.1096
# Saved new best model with validation loss: 0.1096
# Epoch [17/100], Loss: 0.1066
# Saved new best model with validation loss: 0.1066
# Epoch [18/100], Loss: 0.1031
# Saved new best model with validation loss: 0.1031
# Epoch [19/100], Loss: 0.1015
# Saved new best model with validation loss: 0.1015
# Epoch [20/100], Loss: 0.0998
# Saved new best model with validation loss: 0.0998
# Epoch [21/100], Loss: 0.0966
# Saved new best model with validation loss: 0.0966
# Epoch [22/100], Loss: 0.0961
# Saved new best model with validation loss: 0.0961
# Epoch [23/100], Loss: 0.0929
# Saved new best model with validation loss: 0.0929
# Epoch [24/100], Loss: 0.0930
# Epoch [25/100], Loss: 0.0898
# Saved new best model with validation loss: 0.0898
# Epoch [26/100], Loss: 0.0874
# Saved new best model with validation loss: 0.0874
# Epoch [27/100], Loss: 0.0852
# Saved new best model with validation loss: 0.0852
# Epoch [28/100], Loss: 0.0823
# Saved new best model with validation loss: 0.0823
# Epoch [29/100], Loss: 0.0816
# Saved new best model with validation loss: 0.0816
# Epoch [30/100], Loss: 0.0794
# Saved new best model with validation loss: 0.0794
# Epoch [31/100], Loss: 0.0783
# Saved new best model with validation loss: 0.0783
# Epoch [32/100], Loss: 0.0767
# Saved new best model with validation loss: 0.0767
# Epoch [33/100], Loss: 0.0756
# Saved new best model with validation loss: 0.0756
# Epoch [34/100], Loss: 0.0741
# Saved new best model with validation loss: 0.0741
# Epoch [35/100], Loss: 0.0740
# Saved new best model with validation loss: 0.0740
# Epoch [36/100], Loss: 0.0719
# Saved new best model with validation loss: 0.0719
# Epoch [37/100], Loss: 0.0693
# Saved new best model with validation loss: 0.0693
# Epoch [38/100], Loss: 0.0695
# Epoch [39/100], Loss: 0.0672
# Saved new best model with validation loss: 0.0672
# Epoch [40/100], Loss: 0.0664
# Saved new best model with validation loss: 0.0664
# Epoch [41/100], Loss: 0.0649
# Saved new best model with validation loss: 0.0649
# Epoch [42/100], Loss: 0.0645
# Saved new best model with validation loss: 0.0645
# Epoch [43/100], Loss: 0.0627
# Saved new best model with validation loss: 0.0627
# Epoch [44/100], Loss: 0.0615
# Saved new best model with validation loss: 0.0615
# Epoch [45/100], Loss: 0.0602
# Saved new best model with validation loss: 0.0602
# Epoch [46/100], Loss: 0.0585
# Saved new best model with validation loss: 0.0585
# Epoch [47/100], Loss: 0.0574
# Saved new best model with validation loss: 0.0574
# Epoch [48/100], Loss: 0.0568
# Saved new best model with validation loss: 0.0568
# Epoch [49/100], Loss: 0.0553
# Saved new best model with validation loss: 0.0553
# Epoch [50/100], Loss: 0.0544
# Saved new best model with validation loss: 0.0544
# Epoch [51/100], Loss: 0.0534
# Saved new best model with validation loss: 0.0534
# Epoch [52/100], Loss: 0.0516
# Saved new best model with validation loss: 0.0516
# Epoch [53/100], Loss: 0.0510
# Saved new best model with validation loss: 0.0510
# Epoch [54/100], Loss: 0.0510
# Epoch [55/100], Loss: 0.0490
# Saved new best model with validation loss: 0.0490
# Epoch [56/100], Loss: 0.0477
# Saved new best model with validation loss: 0.0477
# Epoch [57/100], Loss: 0.0481
# Epoch [58/100], Loss: 0.0475
# Saved new best model with validation loss: 0.0475
# Epoch [59/100], Loss: 0.0465
# Saved new best model with validation loss: 0.0465
# Epoch [60/100], Loss: 0.0452
# Saved new best model with validation loss: 0.0452
# Epoch [61/100], Loss: 0.0445
# Saved new best model with validation loss: 0.0445
# Epoch [62/100], Loss: 0.0444
# Saved new best model with validation loss: 0.0444
# Epoch [63/100], Loss: 0.0441
# Saved new best model with validation loss: 0.0441
# Epoch [64/100], Loss: 0.0431
# Saved new best model with validation loss: 0.0431
# Epoch [65/100], Loss: 0.0429
# Saved new best model with validation loss: 0.0429
# Epoch [66/100], Loss: 0.0415
# Saved new best model with validation loss: 0.0415
# Epoch [67/100], Loss: 0.0411
# Saved new best model with validation loss: 0.0411
# Epoch [68/100], Loss: 0.0399
# Saved new best model with validation loss: 0.0399
# Epoch [69/100], Loss: 0.0386
# Saved new best model with validation loss: 0.0386
# Epoch [70/100], Loss: 0.0391
# Epoch [71/100], Loss: 0.0380
# Saved new best model with validation loss: 0.0380
# Epoch [72/100], Loss: 0.0380
# Epoch [73/100], Loss: 0.0369
# Saved new best model with validation loss: 0.0369
# Epoch [74/100], Loss: 0.0368
# Saved new best model with validation loss: 0.0368
# Epoch [75/100], Loss: 0.0368
# Epoch [76/100], Loss: 0.0356
# Saved new best model with validation loss: 0.0356
# Epoch [77/100], Loss: 0.0355
# Saved new best model with validation loss: 0.0355
# Epoch [78/100], Loss: 0.0345
# Saved new best model with validation loss: 0.0345
# Epoch [79/100], Loss: 0.0347
# Epoch [80/100], Loss: 0.0339
# Saved new best model with validation loss: 0.0339
# Epoch [81/100], Loss: 0.0337
# Saved new best model with validation loss: 0.0337
# Epoch [82/100], Loss: 0.0335
# Saved new best model with validation loss: 0.0335
# Epoch [83/100], Loss: 0.0337
# Epoch [84/100], Loss: 0.0324
# Saved new best model with validation loss: 0.0324
# Epoch [85/100], Loss: 0.0329
# Epoch [86/100], Loss: 0.0311
# Saved new best model with validation loss: 0.0311
# Epoch [87/100], Loss: 0.0318
# Epoch [88/100], Loss: 0.0303
# Saved new best model with validation loss: 0.0303
# Epoch [89/100], Loss: 0.0297
# Saved new best model with validation loss: 0.0297
# Epoch [90/100], Loss: 0.0299
# Epoch [91/100], Loss: 0.0297
# Saved new best model with validation loss: 0.0297
# Epoch [92/100], Loss: 0.0293
# Saved new best model with validation loss: 0.0293
# Epoch [93/100], Loss: 0.0289
# Saved new best model with validation loss: 0.0289
# Epoch [94/100], Loss: 0.0286
# Saved new best model with validation loss: 0.0286
# Epoch [95/100], Loss: 0.0285
# Saved new best model with validation loss: 0.0285
# Epoch [96/100], Loss: 0.0276
# Saved new best model with validation loss: 0.0276
# Epoch [97/100], Loss: 0.0272
# Saved new best model with validation loss: 0.0272
# Epoch [98/100], Loss: 0.0270
# Saved new best model with validation loss: 0.0270
# Epoch [99/100], Loss: 0.0267
# Saved new best model with validation loss: 0.0267
# Epoch [100/100], Loss: 0.0265
# Saved new best model with validation loss: 0.0265
